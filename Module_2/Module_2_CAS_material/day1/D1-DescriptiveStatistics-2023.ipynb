# %% [markdown]
# Notebook 1, Module 2, Statistical Inference for Data Science, CAS Applied Data Science, 2023-08-29, A. Mühlemann, University of Bern.
#
# *This notebook is based on the notebook by S. Haug and G. Conti from 2020*

# %% [markdown]
# # 1. Descriptive Statistics on Single Features

# %% [markdown]
# **Goals**
# - Graphical preparation of the data
# - Calculate summary statistics

# %% [markdown]
# First load the necessary libraries / modules.

# %%
# Load the needed python libraries by executing this python code (press ctrl enter)
import numpy as np
import scipy.stats
import matplotlib.pyplot as plt
import pandas as pd
import io

# %% [markdown]
# Load the dataset into a dataframe.

# %%
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
df = pd.read_csv(url,names=['slength','swidth','plength','pwidth','species'])
df.head() # Print the first five rows
# Out:
#    slength  swidth  plength  pwidth      species
# 0      5.1     3.5      1.4     0.2  Iris-setosa
# 1      4.9     3.0      1.4     0.2  Iris-setosa
# 2      4.7     3.2      1.3     0.2  Iris-setosa
# 3      4.6     3.1      1.5     0.2  Iris-setosa
# 4      5.0     3.6      1.4     0.2  Iris-setosa

# %% [markdown]
# Browse through all rows.

# %%
pd.set_option('display.max_rows', 200)
df
# Out:
#      slength  swidth  plength  pwidth          species
# 0        5.1     3.5      1.4     0.2      Iris-setosa
# 1        4.9     3.0      1.4     0.2      Iris-setosa
# 2        4.7     3.2      1.3     0.2      Iris-setosa
# 3        4.6     3.1      1.5     0.2      Iris-setosa
# 4        5.0     3.6      1.4     0.2      Iris-setosa
# 5        5.4     3.9      1.7     0.4      Iris-setosa
# 6        4.6     3.4      1.4     0.3      Iris-setosa
# 7        5.0     3.4      1.5     0.2      Iris-setosa
# 8        4.4     2.9      1.4     0.2      Iris-setosa
# 9        4.9     3.1      1.5     0.1      Iris-setosa
# 10       5.4     3.7      1.5     0.2      Iris-setosa
# 11       4.8     3.4      1.6     0.2      Iris-setosa
# 12       4.8     3.0      1.4     0.1      Iris-setosa
# 13       4.3     3.0      1.1     0.1      Iris-setosa
# 14       5.8     4.0      1.2     0.2      Iris-setosa
# 15       5.7     4.4      1.5     0.4      Iris-setosa
# 16       5.4     3.9      1.3     0.4      Iris-setosa
# 17       5.1     3.5      1.4     0.3      Iris-setosa
# 18       5.7     3.8      1.7     0.3      Iris-setosa
# 19       5.1     3.8      1.5     0.3      Iris-setosa
# 20       5.4     3.4      1.7     0.2      Iris-setosa
# 21       5.1     3.7      1.5     0.4      Iris-setosa
# 22       4.6     3.6      1.0     0.2      Iris-setosa
# 23       5.1     3.3      1.7     0.5      Iris-setosa
# 24       4.8     3.4      1.9     0.2      Iris-setosa
# 25       5.0     3.0      1.6     0.2      Iris-setosa
# 26       5.0     3.4      1.6     0.4      Iris-setosa
# 27       5.2     3.5      1.5     0.2      Iris-setosa
# 28       5.2     3.4      1.4     0.2      Iris-setosa
# 29       4.7     3.2      1.6     0.2      Iris-setosa
# 30       4.8     3.1      1.6     0.2      Iris-setosa
# 31       5.4     3.4      1.5     0.4      Iris-setosa
# 32       5.2     4.1      1.5     0.1      Iris-setosa
# 33       5.5     4.2      1.4     0.2      Iris-setosa
# 34       4.9     3.1      1.5     0.1      Iris-setosa
# 35       5.0     3.2      1.2     0.2      Iris-setosa
# 36       5.5     3.5      1.3     0.2      Iris-setosa
# 37       4.9     3.1      1.5     0.1      Iris-setosa
# 38       4.4     3.0      1.3     0.2      Iris-setosa
# 39       5.1     3.4      1.5     0.2      Iris-setosa
# 40       5.0     3.5      1.3     0.3      Iris-setosa
# 41       4.5     2.3      1.3     0.3      Iris-setosa
# 42       4.4     3.2      1.3     0.2      Iris-setosa
# 43       5.0     3.5      1.6     0.6      Iris-setosa
# 44       5.1     3.8      1.9     0.4      Iris-setosa
# 45       4.8     3.0      1.4     0.3      Iris-setosa
# 46       5.1     3.8      1.6     0.2      Iris-setosa
# 47       4.6     3.2      1.4     0.2      Iris-setosa
# 48       5.3     3.7      1.5     0.2      Iris-setosa
# 49       5.0     3.3      1.4     0.2      Iris-setosa
# 50       7.0     3.2      4.7     1.4  Iris-versicolor
# 51       6.4     3.2      4.5     1.5  Iris-versicolor
# 52       6.9     3.1      4.9     1.5  Iris-versicolor
# 53       5.5     2.3      4.0     1.3  Iris-versicolor
# 54       6.5     2.8      4.6     1.5  Iris-versicolor
# 55       5.7     2.8      4.5     1.3  Iris-versicolor
# 56       6.3     3.3      4.7     1.6  Iris-versicolor
# 57       4.9     2.4      3.3     1.0  Iris-versicolor
# 58       6.6     2.9      4.6     1.3  Iris-versicolor
# 59       5.2     2.7      3.9     1.4  Iris-versicolor
# 60       5.0     2.0      3.5     1.0  Iris-versicolor
# 61       5.9     3.0      4.2     1.5  Iris-versicolor
# 62       6.0     2.2      4.0     1.0  Iris-versicolor
# 63       6.1     2.9      4.7     1.4  Iris-versicolor
# 64       5.6     2.9      3.6     1.3  Iris-versicolor
# 65       6.7     3.1      4.4     1.4  Iris-versicolor
# 66       5.6     3.0      4.5     1.5  Iris-versicolor
# 67       5.8     2.7      4.1     1.0  Iris-versicolor
# 68       6.2     2.2      4.5     1.5  Iris-versicolor
# 69       5.6     2.5      3.9     1.1  Iris-versicolor
# 70       5.9     3.2      4.8     1.8  Iris-versicolor
# 71       6.1     2.8      4.0     1.3  Iris-versicolor
# 72       6.3     2.5      4.9     1.5  Iris-versicolor
# 73       6.1     2.8      4.7     1.2  Iris-versicolor
# 74       6.4     2.9      4.3     1.3  Iris-versicolor
# 75       6.6     3.0      4.4     1.4  Iris-versicolor
# 76       6.8     2.8      4.8     1.4  Iris-versicolor
# 77       6.7     3.0      5.0     1.7  Iris-versicolor
# 78       6.0     2.9      4.5     1.5  Iris-versicolor
# 79       5.7     2.6      3.5     1.0  Iris-versicolor
# 80       5.5     2.4      3.8     1.1  Iris-versicolor
# 81       5.5     2.4      3.7     1.0  Iris-versicolor
# 82       5.8     2.7      3.9     1.2  Iris-versicolor
# 83       6.0     2.7      5.1     1.6  Iris-versicolor
# 84       5.4     3.0      4.5     1.5  Iris-versicolor
# 85       6.0     3.4      4.5     1.6  Iris-versicolor
# 86       6.7     3.1      4.7     1.5  Iris-versicolor
# 87       6.3     2.3      4.4     1.3  Iris-versicolor
# 88       5.6     3.0      4.1     1.3  Iris-versicolor
# 89       5.5     2.5      4.0     1.3  Iris-versicolor
# 90       5.5     2.6      4.4     1.2  Iris-versicolor
# 91       6.1     3.0      4.6     1.4  Iris-versicolor
# 92       5.8     2.6      4.0     1.2  Iris-versicolor
# 93       5.0     2.3      3.3     1.0  Iris-versicolor
# 94       5.6     2.7      4.2     1.3  Iris-versicolor
# 95       5.7     3.0      4.2     1.2  Iris-versicolor
# 96       5.7     2.9      4.2     1.3  Iris-versicolor
# 97       6.2     2.9      4.3     1.3  Iris-versicolor
# 98       5.1     2.5      3.0     1.1  Iris-versicolor
# 99       5.7     2.8      4.1     1.3  Iris-versicolor
# 100      6.3     3.3      6.0     2.5   Iris-virginica
# 101      5.8     2.7      5.1     1.9   Iris-virginica
# 102      7.1     3.0      5.9     2.1   Iris-virginica
# 103      6.3     2.9      5.6     1.8   Iris-virginica
# 104      6.5     3.0      5.8     2.2   Iris-virginica
# 105      7.6     3.0      6.6     2.1   Iris-virginica
# 106      4.9     2.5      4.5     1.7   Iris-virginica
# 107      7.3     2.9      6.3     1.8   Iris-virginica
# 108      6.7     2.5      5.8     1.8   Iris-virginica
# 109      7.2     3.6      6.1     2.5   Iris-virginica
# 110      6.5     3.2      5.1     2.0   Iris-virginica
# 111      6.4     2.7      5.3     1.9   Iris-virginica
# 112      6.8     3.0      5.5     2.1   Iris-virginica
# 113      5.7     2.5      5.0     2.0   Iris-virginica
# 114      5.8     2.8      5.1     2.4   Iris-virginica
# 115      6.4     3.2      5.3     2.3   Iris-virginica
# 116      6.5     3.0      5.5     1.8   Iris-virginica
# 117      7.7     3.8      6.7     2.2   Iris-virginica
# 118      7.7     2.6      6.9     2.3   Iris-virginica
# 119      6.0     2.2      5.0     1.5   Iris-virginica
# 120      6.9     3.2      5.7     2.3   Iris-virginica
# 121      5.6     2.8      4.9     2.0   Iris-virginica
# 122      7.7     2.8      6.7     2.0   Iris-virginica
# 123      6.3     2.7      4.9     1.8   Iris-virginica
# 124      6.7     3.3      5.7     2.1   Iris-virginica
# 125      7.2     3.2      6.0     1.8   Iris-virginica
# 126      6.2     2.8      4.8     1.8   Iris-virginica
# 127      6.1     3.0      4.9     1.8   Iris-virginica
# 128      6.4     2.8      5.6     2.1   Iris-virginica
# 129      7.2     3.0      5.8     1.6   Iris-virginica
# 130      7.4     2.8      6.1     1.9   Iris-virginica
# 131      7.9     3.8      6.4     2.0   Iris-virginica
# 132      6.4     2.8      5.6     2.2   Iris-virginica
# 133      6.3     2.8      5.1     1.5   Iris-virginica
# 134      6.1     2.6      5.6     1.4   Iris-virginica
# 135      7.7     3.0      6.1     2.3   Iris-virginica
# 136      6.3     3.4      5.6     2.4   Iris-virginica
# 137      6.4     3.1      5.5     1.8   Iris-virginica
# 138      6.0     3.0      4.8     1.8   Iris-virginica
# 139      6.9     3.1      5.4     2.1   Iris-virginica
# 140      6.7     3.1      5.6     2.4   Iris-virginica
# 141      6.9     3.1      5.1     2.3   Iris-virginica
# 142      5.8     2.7      5.1     1.9   Iris-virginica
# 143      6.8     3.2      5.9     2.3   Iris-virginica
# 144      6.7     3.3      5.7     2.5   Iris-virginica
# 145      6.7     3.0      5.2     2.3   Iris-virginica
# 146      6.3     2.5      5.0     1.9   Iris-virginica
# 147      6.5     3.0      5.2     2.0   Iris-virginica
# 148      6.2     3.4      5.4     2.3   Iris-virginica
# 149      5.9     3.0      5.1     1.8   Iris-virginica

# %% [markdown]
# ## 1.1 Graphical Analyis
# ### 1.1.1 Pie chart and bar plot (categorical variables)
# Pie charts are used to show proportions of a whole.
#
# We could, for example, ask ourselves, whether an equal number of specimens from each species have been examined.

# %%
df.groupby('species').size().plot(kind='pie', autopct='%1.1f%%' ,ylabel="")
# Out:
# <Axes: >

# %% [markdown]
# The problem with pie charts is that if there are many groups we tend missinterpret the pie slices (https://www.data-to-viz.com/caveat/pie.html). Thus, it often is reasonable sense to use a barplot instead.

# %%
df.groupby('species').size().plot(kind='barh' ,ylabel="")
# Out:
# <Axes: >

# %% [markdown]
# ## 1.1.2 Histogram (numerical variables)
# Histograms are used to display frequencies or proportions.
#
# For example, we could use an histogram to analyze different characteristics whitin the species *iris setosa*.

# %%
df_setosa =df[df['species']=='Iris-setosa']

plt.figure(figsize=(8  ,8))
plt.subplot(2,2,1)
df_setosa['slength'].plot(kind="hist",fill=True,histtype='barstacked',title='Iris Setosa Setal', label="length", color= 'tab:blue')
ax_s = df_setosa['swidth'].plot(kind="hist",fill=True,histtype='barstacked', label="width",  color= 'tab:orange')
ax_s.set_xlabel('x [cm]')
ax_s.set_ylabel('absolute frequency')
plt.legend()

plt.subplot(2,2,2)
df_setosa['plength'].plot(kind="hist",fill=False,histtype='step',title='Iris Setosa Petal', label="length")
ax_s = df_setosa['pwidth'].plot(kind="hist",fill=False,histtype='step', label="width")
ax_s.set_xlabel('x [cm]')
ax_s.set_ylabel('absolute frequency')
plt.legend()

plt.show()

# %% [markdown]
# ### 1.1.3 Scatter plot colored by species (simulatneous description)
#
# Scatter plots use dots to represent values for two different numeric variables.
#
# For example, we could look at the species and one of the numerical characteristics simulatneously.

# %%
color=np.repeat(np.array(['red', 'pink', 'purple']), [50, 50, 50], axis=0)
df1=pd.DataFrame(dict(col=color))
df2=pd.concat([df, df1], axis=1)

plt.figure(figsize=(8  ,8))

plt.subplot(2,2,1)
plt.scatter(df2['species'], df2['slength'], c=df2['col'])
plt.title('slength')
plt.ylabel('slength')

plt.subplot(2,2,3)
plt.scatter(df2['species'], df2['plength'], c=df2['col'])
plt.title('plength')
plt.ylabel('plength')

plt.subplot(2,2,2)
plt.scatter(df2['species'], df2['swidth'], c=df2['col'])
plt.title('swidth')
plt.ylabel('swidth')

plt.subplot(2,2,4)
plt.scatter(df2['species'], df2['pwidth'], c=df2['col'])
plt.title('pwidth')
plt.ylabel('pwidth')

plt.tight_layout(h_pad=2, w_pad=2)
plt.show()

# %% [markdown]
# What can you see in this picture?

# %% [markdown]
# # 1.2 Numerical analysis
#
# # 1.2.1 Location
#
# Location measures are used to describe typical values of a variable. Best known are the mean and the median.

# %%
grouped_df = df.groupby("species") # group by species, so we get means for all species seperately
print(grouped_df.mean())
grouped_df.mean()
# Out:
#                  slength  swidth  plength  pwidth
# species
# Iris-setosa        5.006   3.418    1.464   0.244
# Iris-versicolor    5.936   2.770    4.260   1.326
# Iris-virginica     6.588   2.974    5.552   2.026
#                  slength  swidth  plength  pwidth
# species
# Iris-setosa        5.006   3.418    1.464   0.244
# Iris-versicolor    5.936   2.770    4.260   1.326
# Iris-virginica     6.588   2.974    5.552   2.026

# %%
grouped_df.median()
# Out:
#                  slength  swidth  plength  pwidth
# species
# Iris-setosa          5.0     3.4     1.50     0.2
# Iris-versicolor      5.9     2.8     4.35     1.3
# Iris-virginica       6.5     3.0     5.55     2.0

# %% [markdown]
# Do the means and medians support your observations from the pictures?
#
# ## 1.2.2 Spread
#
# Typical values are interesting but sometimes more information is needed. It is for example also of interest to see how spead the values are. Typical measures for the spread are the variance, standard deviation, inter quartile range, etc.

# %%
grouped_df.std()
# Out:
#                   slength    swidth   plength    pwidth
# species
# Iris-setosa      0.352490  0.381024  0.173511  0.107210
# Iris-versicolor  0.516171  0.313798  0.469911  0.197753
# Iris-virginica   0.635880  0.322497  0.551895  0.274650

# %% [markdown]
# Which characteristic has the largest standard deviation? What is the definition of the standard deviation?
#
# We can also look at the IQR.

# %%
#define function to calculate interquartile range
def find_iqr(x):
  return np.subtract(*np.percentile(x, [75, 25]))
# calculate IDR for plength for each species
grouped_df['plength'].apply(find_iqr)
#grouped_df['plength'].quantile(0.75)-grouped_df['plength'].quantile(0.25)
# Out:
# species
# Iris-setosa        0.175
# Iris-versicolor    0.600
# Iris-virginica     0.775
# Name: plength, dtype: float64

# %% [markdown]
# Compare the standard deviation of plength with its IQR.
# (Information on the *-operator: https://treyhunner.com/2018/10/asterisks-in-python-what-they-are-and-how-to-use-them/)

# %% [markdown]
# Alternatively, one can also get most of those measures with a single command:

# %%
grouped_df.describe()
# Out:
#                 slength                                             swidth  \
#                   count   mean       std  min    25%  50%  75%  max  count
# species
# Iris-setosa        50.0  5.006  0.352490  4.3  4.800  5.0  5.2  5.8   50.0
# Iris-versicolor    50.0  5.936  0.516171  4.9  5.600  5.9  6.3  7.0   50.0
# Iris-virginica     50.0  6.588  0.635880  4.9  6.225  6.5  6.9  7.9   50.0
#
#                         ... plength      pwidth                             \
#                   mean  ...     75%  max  count   mean       std  min  25%
# species                 ...
# Iris-setosa      3.418  ...   1.575  1.9   50.0  0.244  0.107210  0.1  0.2
# Iris-versicolor  2.770  ...   4.600  5.1   50.0  1.326  0.197753  1.0  1.2
# Iris-virginica   2.974  ...   5.875  6.9   50.0  2.026  0.274650  1.4  1.8
#
#
#                  50%  75%  max
# species
# Iris-setosa      0.2  0.3  0.6
# Iris-versicolor  1.3  1.5  1.8
# Iris-virginica   2.0  2.3  2.5
#
# [3 rows x 32 columns]

# %% [markdown]
# However, this output is not very comprehensible. Here it makes more sense to consider only one species for the summary:

# %%
df[df['species']=='Iris-setosa'].describe()
# Out:
#         slength     swidth    plength    pwidth
# count  50.00000  50.000000  50.000000  50.00000
# mean    5.00600   3.418000   1.464000   0.24400
# std     0.35249   0.381024   0.173511   0.10721
# min     4.30000   2.300000   1.000000   0.10000
# 25%     4.80000   3.125000   1.400000   0.20000
# 50%     5.00000   3.400000   1.500000   0.20000
# 75%     5.20000   3.675000   1.575000   0.30000
# max     5.80000   4.400000   1.900000   0.60000

# %% [markdown]
# Do all these digits after the comma make sense?

# %% [markdown]
# ## 1.2.3 Shape
#
# Another measure that is often looked at is the shape of the distribution. The mostly used measures are the skewness and the kurtosis.

# %%
grouped_df.skew()
# Out:
#                   slength    swidth   plength    pwidth
# species
# Iris-setosa      0.120087  0.107053  0.071846  1.197243
# Iris-versicolor  0.105378 -0.362845 -0.606508 -0.031180
# Iris-virginica   0.118015  0.365949  0.549445 -0.129477

# %% [markdown]
# The skewness of *iris setosa* is $>0$ for all characteristics. What does that mean?

# %% [markdown]
# that all the values are not matching a normal distrubution and that there is a tendency for smaller flowers and less big flowers this is more pronunce in the pwith...i cannot see in the scatter plots...??

# %% [markdown]
# Now let us look at the kurtosis.

# %%
grouped_df.apply(pd.DataFrame.kurt, numeric_only=True)
# Out:
#                   slength    swidth   plength    pwidth
# species
# Iris-setosa     -0.252689  0.889251  1.031626  1.566442
# Iris-versicolor -0.533010 -0.366237  0.047903 -0.410059
# Iris-virginica   0.032904  0.706071 -0.153779 -0.602264

# %% [markdown]
# The idea behind the kurtosis is the following:
# Some numerical characteristics, when the sample size is large and the intervals are small, result in a histogram that resembles a Gaussian bell curve. In this case, the value of the kurtosis is close to zero. If the tails are heavier than you would expect for a Gaussian distribution the kurtosis will be substantially positive. If the tails are less heavy than you would expect for a Gaussian distribution the kurtosis will be negative.

# %% [markdown]
# ## 1.7 Outlook
# The characteristic *slength* from of the species *iris virginica* has a kurtosis close to zero. Moreover, its skewness is close to 0. Therefore, a Gaussian model would probably be suitable. To get an idea whether this is plausible let us  compare the histogram to the Gaussian density function.
#
# When looking at hypothesis testing, we will see how to test this mathematically.
#
# Our model is a normal distribution with the mean and width taken from the dataset: **norm.pdf(x,mean,width)**.

# %%
df_virginica=df[df['species']=='Iris-virginica']
from scipy.stats import norm
mean  = df_virginica['slength'].mean()
width = df_virginica['slength'].std()
print(mean,width)
# Create figure and axis
fig, ax = plt.subplots(1,1)
# Create 100 x values and plot the normal pdf for these values
#x = np.linspace(norm.ppf(0.01),norm.ppf(0.99), 100)
x = np.linspace(4,10,80)
ax.plot(x, norm.pdf(x,mean,width),'b-', lw=2, label='Normed pdf')
df_virginica['slength'].plot(kind="hist",fill=False,histtype='step',title='Iris Virginica Setal', label="length", density="True")
ax.legend(loc='best', frameon=False)
plt.show()
# Out:
# 6.587999999999998 0.6358795932744322

# %% [markdown]
# With this model we could now do a lot of inference. Taking a random leave, one could for example test how likely it is to be Iris Viginica.

# %% [markdown]
# # 2. Simultaneous Description of two Features

# %% [markdown]
# In the first part of this notebook, we only looked at individual characteristics. For example, we calculated the mean *slength* of *iris setosa*. Of course, we did this simultaneously for all characteristics and species, but we never compared two characteristics directly. That is what we would like to do now.

# %% [markdown]
# ## 2.1 Graphical Analysis
#
# ### 2.1.1 Boxplots
#
# A boxplot is a graphical display of the minimum, maximum, and the 3 quartiles.
# For example, could we display distributions of *slength* for the 3 species.

# %%
df_slength=df[['slength', 'species']]
fig, ax = plt.subplots(1,1)
df_slength.pivot(columns='species', values='slength').boxplot()
ax.set_title('slength')
# Out:
# Text(0.5, 1.0, 'slength')

# %% [markdown]
# ### 2.1.2 Scatter matrix
#
# Now let us see whether some of the features correlate. To this end, we look at the scatter plots of the different characterisics for *iris setosa*.

# %%
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.plotting.scatter_matrix.html
from pandas.plotting import scatter_matrix
scatter_matrix(df[df['species']=='Iris-setosa'], alpha=0.2, figsize=(6, 6), diagonal='hist')
plt.show()

# %% [markdown]
# The scatter plot in the first row and second colum suggests that there is some relationship between *slength* and *swidth*. It seems that the larger *swidth* is the larger is also *slength*.

# %% [markdown]
# ## 2.2 Numerical Analyis
#
# ### 2.3 Correlation
# To get more information on the correlation between two variables the correlation coefficient is calculated.
#
# Let's see whether the correlation coefficient does support this observation.
#
# **Caution**: correlation not equals causation!!

# %%
df[df['species']=='Iris-setosa'].corr()
# Out:
#           slength    swidth   plength    pwidth
# slength  1.000000  0.746780  0.263874  0.279092
# swidth   0.746780  1.000000  0.176695  0.279973
# plength  0.263874  0.176695  1.000000  0.306308
# pwidth   0.279092  0.279973  0.306308  1.000000

# %%
#seems to be a linear correlation between slenght and swidth

# %% [markdown]
# What is the definition of the correlation?

# %% [markdown]
# What kind of relationship between *swidth* and *slength* does the correlation coefficient suggest?

# %% [markdown]
# How about the other species?

# %%
color=np.repeat(np.array(['red', 'pink', 'purple']), [50, 50, 50], axis=0)
df1=pd.DataFrame(dict(col=color))
print(df1)
df2=pd.concat([df, df1], axis=1)
print(df2)
plt.figure(figsize=(8  ,8))

plt.subplot(2,2,1)
plt.scatter(df2['slength'], df2['swidth'], c=df2['col'])
plt.xlabel('slength')
plt.ylabel('swidth')

plt.subplot(2,2,2)
plt.scatter(df2['plength'], df2['pwidth'], c=df2['col'])
plt.xlabel('plength')
plt.ylabel('pwidth')

plt.tight_layout(h_pad=2, w_pad=2)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#         col
# 0       red
# 1       red
# 2       red
# 3       red
# 4       red
# 5       red
# 6       red
# 7       red
# 8       red
# 9       red
# 10      red
# 11      red
# 12      red
# 13      red
# 14      red
# 15      red
# 16      red
# 17      red
# 18      red
# 19      red
# 20      red
# 21      red
# 22      red
# 23      red
# 24      red
# 25      red
# 26      red
# 27      red
# 28      red
# 29      red
# 30      red
# 31      red
# 32      red
# 33      red
# 34      red
# 35      red
# 36      red
# 37      red
# 38      red
# 39      red
# 40      red
# 41      red
# 42      red
# 43      red
# 44      red
# 45      red
# 46      red
# 47      red
# 48      red
# 49      red
# 50     pink
# 51     pink
# 52     pink
# 53     pink
# 54     pink
# 55     pink
# 56     pink
# 57     pink
# 58     pink
# 59     pink
# 60     pink
# 61     pink
# 62     pink
# 63     pink
# 64     pink
# 65     pink
# 66     pink
# 67     pink
# 68     pink
# 69     pink
# 70     pink
# 71     pink
# 72     pink
# 73     pink
# 74     pink
# 75     pink
# 76     pink
# 77     pink
# 78     pink
# 79     pink
# 80     pink
# 81     pink
# 82     pink
# 83     pink
# 84     pink
# 85     pink
# 86     pink
# 87     pink
# 88     pink
# 89     pink
# 90     pink
# 91     pink
# 92     pink
# 93     pink
# 94     pink
# 95     pink
# 96     pink
# 97     pink
# 98     pink
# 99     pink
# 100  purple
# 101  purple
# 102  purple
# 103  purple
# 104  purple
# 105  purple
# 106  purple
# 107  purple
# 108  purple
# 109  purple
# 110  purple
# 111  purple
# 112  purple
# 113  purple
# 114  purple
# 115  purple
# 116  purple
# 117  purple
# 118  purple
# 119  purple
# 120  purple
# 121  purple
# 122  purple
# 123  purple
# 124  purple
# 125  purple
# 126  purple
# 127  purple
# 128  purple
# 129  purple
# 130  purple
# 131  purple
# 132  purple
# 133  purple
# 134  purple
# 135  purple
# 136  purple
# 137  purple
# 138  purple
# 139  purple
# 140  purple
# 141  purple
# 142  purple
# 143  purple
# 144  purple
# 145  purple
# 146  purple
# 147  purple
# 148  purple
# 149  purple
#      slength  swidth  plength  pwidth          species     col
# 0        5.1     3.5      1.4     0.2      Iris-setosa     red
# 1        4.9     3.0      1.4     0.2      Iris-setosa     red
# 2        4.7     3.2      1.3     0.2      Iris-setosa     red
# 3        4.6     3.1      1.5     0.2      Iris-setosa     red
# 4        5.0     3.6      1.4     0.2      Iris-setosa     red
# 5        5.4     3.9      1.7     0.4      Iris-setosa     red
# 6        4.6     3.4      1.4     0.3      Iris-setosa     red
# 7        5.0     3.4      1.5     0.2      Iris-setosa     red
# 8        4.4     2.9      1.4     0.2      Iris-setosa     red
# 9        4.9     3.1      1.5     0.1      Iris-setosa     red
# 10       5.4     3.7      1.5     0.2      Iris-setosa     red
# 11       4.8     3.4      1.6     0.2      Iris-setosa     red
# 12       4.8     3.0      1.4     0.1      Iris-setosa     red
# 13       4.3     3.0      1.1     0.1      Iris-setosa     red
# 14       5.8     4.0      1.2     0.2      Iris-setosa     red
# 15       5.7     4.4      1.5     0.4      Iris-setosa     red
# 16       5.4     3.9      1.3     0.4      Iris-setosa     red
# 17       5.1     3.5      1.4     0.3      Iris-setosa     red
# 18       5.7     3.8      1.7     0.3      Iris-setosa     red
# 19       5.1     3.8      1.5     0.3      Iris-setosa     red
# 20       5.4     3.4      1.7     0.2      Iris-setosa     red
# 21       5.1     3.7      1.5     0.4      Iris-setosa     red
# 22       4.6     3.6      1.0     0.2      Iris-setosa     red
# 23       5.1     3.3      1.7     0.5      Iris-setosa     red
# 24       4.8     3.4      1.9     0.2      Iris-setosa     red
# 25       5.0     3.0      1.6     0.2      Iris-setosa     red
# 26       5.0     3.4      1.6     0.4      Iris-setosa     red
# 27       5.2     3.5      1.5     0.2      Iris-setosa     red
# 28       5.2     3.4      1.4     0.2      Iris-setosa     red
# 29       4.7     3.2      1.6     0.2      Iris-setosa     red
# 30       4.8     3.1      1.6     0.2      Iris-setosa     red
# 31       5.4     3.4      1.5     0.4      Iris-setosa     red
# 32       5.2     4.1      1.5     0.1      Iris-setosa     red
# 33       5.5     4.2      1.4     0.2      Iris-setosa     red
# 34       4.9     3.1      1.5     0.1      Iris-setosa     red
# 35       5.0     3.2      1.2     0.2      Iris-setosa     red
# 36       5.5     3.5      1.3     0.2      Iris-setosa     red
# 37       4.9     3.1      1.5     0.1      Iris-setosa     red
# 38       4.4     3.0      1.3     0.2      Iris-setosa     red
# 39       5.1     3.4      1.5     0.2      Iris-setosa     red
# 40       5.0     3.5      1.3     0.3      Iris-setosa     red
# 41       4.5     2.3      1.3     0.3      Iris-setosa     red
# 42       4.4     3.2      1.3     0.2      Iris-setosa     red
# 43       5.0     3.5      1.6     0.6      Iris-setosa     red
# 44       5.1     3.8      1.9     0.4      Iris-setosa     red
# 45       4.8     3.0      1.4     0.3      Iris-setosa     red
# 46       5.1     3.8      1.6     0.2      Iris-setosa     red
# 47       4.6     3.2      1.4     0.2      Iris-setosa     red
# 48       5.3     3.7      1.5     0.2      Iris-setosa     red
# 49       5.0     3.3      1.4     0.2      Iris-setosa     red
# 50       7.0     3.2      4.7     1.4  Iris-versicolor    pink
# 51       6.4     3.2      4.5     1.5  Iris-versicolor    pink
# 52       6.9     3.1      4.9     1.5  Iris-versicolor    pink
# 53       5.5     2.3      4.0     1.3  Iris-versicolor    pink
# 54       6.5     2.8      4.6     1.5  Iris-versicolor    pink
# 55       5.7     2.8      4.5     1.3  Iris-versicolor    pink
# 56       6.3     3.3      4.7     1.6  Iris-versicolor    pink
# 57       4.9     2.4      3.3     1.0  Iris-versicolor    pink
# 58       6.6     2.9      4.6     1.3  Iris-versicolor    pink
# 59       5.2     2.7      3.9     1.4  Iris-versicolor    pink
# 60       5.0     2.0      3.5     1.0  Iris-versicolor    pink
# 61       5.9     3.0      4.2     1.5  Iris-versicolor    pink
# 62       6.0     2.2      4.0     1.0  Iris-versicolor    pink
# 63       6.1     2.9      4.7     1.4  Iris-versicolor    pink
# 64       5.6     2.9      3.6     1.3  Iris-versicolor    pink
# 65       6.7     3.1      4.4     1.4  Iris-versicolor    pink
# 66       5.6     3.0      4.5     1.5  Iris-versicolor    pink
# 67       5.8     2.7      4.1     1.0  Iris-versicolor    pink
# 68       6.2     2.2      4.5     1.5  Iris-versicolor    pink
# 69       5.6     2.5      3.9     1.1  Iris-versicolor    pink
# 70       5.9     3.2      4.8     1.8  Iris-versicolor    pink
# 71       6.1     2.8      4.0     1.3  Iris-versicolor    pink
# 72       6.3     2.5      4.9     1.5  Iris-versicolor    pink
# 73       6.1     2.8      4.7     1.2  Iris-versicolor    pink
# 74       6.4     2.9      4.3     1.3  Iris-versicolor    pink
# 75       6.6     3.0      4.4     1.4  Iris-versicolor    pink
# 76       6.8     2.8      4.8     1.4  Iris-versicolor    pink
# 77       6.7     3.0      5.0     1.7  Iris-versicolor    pink
# 78       6.0     2.9      4.5     1.5  Iris-versicolor    pink
# 79       5.7     2.6      3.5     1.0  Iris-versicolor    pink
# 80       5.5     2.4      3.8     1.1  Iris-versicolor    pink
# 81       5.5     2.4      3.7     1.0  Iris-versicolor    pink
# 82       5.8     2.7      3.9     1.2  Iris-versicolor    pink
# 83       6.0     2.7      5.1     1.6  Iris-versicolor    pink
# 84       5.4     3.0      4.5     1.5  Iris-versicolor    pink
# 85       6.0     3.4      4.5     1.6  Iris-versicolor    pink
# 86       6.7     3.1      4.7     1.5  Iris-versicolor    pink
# 87       6.3     2.3      4.4     1.3  Iris-versicolor    pink
# 88       5.6     3.0      4.1     1.3  Iris-versicolor    pink
# 89       5.5     2.5      4.0     1.3  Iris-versicolor    pink
# 90       5.5     2.6      4.4     1.2  Iris-versicolor    pink
# 91       6.1     3.0      4.6     1.4  Iris-versicolor    pink
# 92       5.8     2.6      4.0     1.2  Iris-versicolor    pink
# 93       5.0     2.3      3.3     1.0  Iris-versicolor    pink
# 94       5.6     2.7      4.2     1.3  Iris-versicolor    pink
# 95       5.7     3.0      4.2     1.2  Iris-versicolor    pink
# 96       5.7     2.9      4.2     1.3  Iris-versicolor    pink
# 97       6.2     2.9      4.3     1.3  Iris-versicolor    pink
# 98       5.1     2.5      3.0     1.1  Iris-versicolor    pink
# 99       5.7     2.8      4.1     1.3  Iris-versicolor    pink
# 100      6.3     3.3      6.0     2.5   Iris-virginica  purple
# 101      5.8     2.7      5.1     1.9   Iris-virginica  purple
# 102      7.1     3.0      5.9     2.1   Iris-virginica  purple
# 103      6.3     2.9      5.6     1.8   Iris-virginica  purple
# 104      6.5     3.0      5.8     2.2   Iris-virginica  purple
# 105      7.6     3.0      6.6     2.1   Iris-virginica  purple
# 106      4.9     2.5      4.5     1.7   Iris-virginica  purple
# 107      7.3     2.9      6.3     1.8   Iris-virginica  purple
# 108      6.7     2.5      5.8     1.8   Iris-virginica  purple
# 109      7.2     3.6      6.1     2.5   Iris-virginica  purple
# 110      6.5     3.2      5.1     2.0   Iris-virginica  purple
# 111      6.4     2.7      5.3     1.9   Iris-virginica  purple
# 112      6.8     3.0      5.5     2.1   Iris-virginica  purple
# 113      5.7     2.5      5.0     2.0   Iris-virginica  purple
# 114      5.8     2.8      5.1     2.4   Iris-virginica  purple
# 115      6.4     3.2      5.3     2.3   Iris-virginica  purple
# 116      6.5     3.0      5.5     1.8   Iris-virginica  purple
# 117      7.7     3.8      6.7     2.2   Iris-virginica  purple
# 118      7.7     2.6      6.9     2.3   Iris-virginica  purple
# 119      6.0     2.2      5.0     1.5   Iris-virginica  purple
# 120      6.9     3.2      5.7     2.3   Iris-virginica  purple
# 121      5.6     2.8      4.9     2.0   Iris-virginica  purple
# 122      7.7     2.8      6.7     2.0   Iris-virginica  purple
# 123      6.3     2.7      4.9     1.8   Iris-virginica  purple
# 124      6.7     3.3      5.7     2.1   Iris-virginica  purple
# 125      7.2     3.2      6.0     1.8   Iris-virginica  purple
# 126      6.2     2.8      4.8     1.8   Iris-virginica  purple
# 127      6.1     3.0      4.9     1.8   Iris-virginica  purple
# 128      6.4     2.8      5.6     2.1   Iris-virginica  purple
# 129      7.2     3.0      5.8     1.6   Iris-virginica  purple
# 130      7.4     2.8      6.1     1.9   Iris-virginica  purple
# 131      7.9     3.8      6.4     2.0   Iris-virginica  purple
# 132      6.4     2.8      5.6     2.2   Iris-virginica  purple
# 133      6.3     2.8      5.1     1.5   Iris-virginica  purple
# 134      6.1     2.6      5.6     1.4   Iris-virginica  purple
# 135      7.7     3.0      6.1     2.3   Iris-virginica  purple
# 136      6.3     3.4      5.6     2.4   Iris-virginica  purple
# 137      6.4     3.1      5.5     1.8   Iris-virginica  purple
# 138      6.0     3.0      4.8     1.8   Iris-virginica  purple
# 139      6.9     3.1      5.4     2.1   Iris-virginica  purple
# 140      6.7     3.1      5.6     2.4   Iris-virginica  purple
# 141      6.9     3.1      5.1     2.3   Iris-virginica  purple
# 142      5.8     2.7      5.1     1.9   Iris-virginica  purple
# 143      6.8     3.2      5.9     2.3   Iris-virginica  purple
# 144      6.7     3.3      5.7     2.5   Iris-virginica  purple
# 145      6.7     3.0      5.2     2.3   Iris-virginica  purple
# 146      6.3     2.5      5.0     1.9   Iris-virginica  purple
# 147      6.5     3.0      5.2     2.0   Iris-virginica  purple
# 148      6.2     3.4      5.4     2.3   Iris-virginica  purple
# 149      5.9     3.0      5.1     1.8   Iris-virginica  purple

# %% [markdown]
# ## Remark
#
# This was only a short overview on what can be done and on how these approaches can be implemented using python. Of course there are many more options that could be explored.
